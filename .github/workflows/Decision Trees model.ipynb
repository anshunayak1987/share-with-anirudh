# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.utils.random import sample_without_replacement
from sklearn.utils import resample
from sklearn.metrics import confusion_matrix, classification_report

# %%
data_csv = "./Resources/glassdoor_reviews_clean.csv"
data_csv = pd.read_csv(data_csv)
data_csv
# Out:
#         Unnamed: 0                   firm date_review  \
# 0               50  AFH-Wealth-Management  2020-10-01
# 1               51  AFH-Wealth-Management  2021-02-05
# 2               52  AFH-Wealth-Management  2021-02-07
# 3               53  AFH-Wealth-Management  2021-02-07
# 4               60  AFH-Wealth-Management  2021-05-12
# ...            ...                    ...         ...
# 108622      838556         the-LEGO-Group  2021-05-21
# 108623      838558         the-LEGO-Group  2021-05-25
# 108624      838560         the-LEGO-Group  2021-05-31
# 108625      838561         the-LEGO-Group  2021-06-02
# 108626      838565         the-LEGO-Group  2021-06-04
#
#                                   job_title  \
# 0                      Office Administrator
# 1                           Quality Control
# 2                         IFA Administrator
# 3                     Investment Operations
# 4               Client Engagement Executive
# ...                                     ...
# 108622   Sales Associate (Brick Specialist)
# 108623               Senior Product Manager
# 108624           Senior Experience Designer
# 108625                    Marketing Manager
# 108626           Human Resources Specialist
#
#                                     current  \
# 0        Former Employee, more than 3 years
# 1                           Former Employee
# 2         Former Employee, less than 1 year
# 3         Former Employee, more than 1 year
# 4         Former Employee, less than 1 year
# ...                                     ...
# 108622    Former Employee, less than 1 year
# 108623                     Current Employee
# 108624   Current Employee, less than 1 year
# 108625  Current Employee, more than 5 years
# 108626  Current Employee, more than 3 years
#
#                                           location  overall_rating  \
# 0                     Bromsgrove, England, England               2
# 1                     Birmingham, England, England               1
# 2                     Bromsgrove, England, England               4
# 3                     Birmingham, England, England               3
# 4                     Birmingham, England, England               1
# ...                                            ...             ...
# 108622                             Bloomington, MN               4
# 108623                    London, England, England               4
# 108624                                     Billund               5
# 108625                   München, Bavaria, Bavaria               5
# 108626  Kladno, Central Bohemian, Central Bohemian               5
#
#         work_life_balance  culture_values  diversity_inclusion  career_opp  \
# 0                     1.0             3.0                  1.0         1.0
# 1                     3.0             1.0                  2.0         1.0
# 2                     3.0             3.0                  4.0         4.0
# 3                     5.0             5.0                  4.0         3.0
# 4                     1.0             2.0                  1.0         1.0
# ...                   ...             ...                  ...         ...
# 108622                5.0             4.0                  5.0         4.0
# 108623                3.0             4.0                  2.0         3.0
# 108624                5.0             5.0                  5.0         5.0
# 108625                4.0             5.0                  4.0         4.0
# 108626                4.0             5.0                  4.0         4.0
#
#         comp_benefits  senior_mgmt recommend ceo_approv outlook  \
# 0                 2.0          2.0         x          o       x
# 1                 1.0          1.0         x          o       o
# 2                 4.0          2.0         v          o       v
# 3                 1.0          2.0         x          o       v
# 4                 1.0          1.0         x          x       x
# ...               ...          ...       ...        ...     ...
# 108622            2.0          5.0         v          v       v
# 108623            2.0          3.0         v          r       v
# 108624            5.0          5.0         v          v       v
# 108625            4.0          4.0         v          v       v
# 108626            5.0          5.0         v          v       o
#
#                                                headline  \
# 0           The people both make and destroy this place
# 1                                     Very low salaries
# 2                                                  Good
# 3                                            AFH Review
# 4                       Terrible- avoid like the plague
# ...                                                 ...
# 108622                  Working at LEGO was pretty cool
# 108623                                    A great brand
# 108624                            Awesome place to work
# 108625           Just an awesome company to work for!!!
# 108626  I strongly recommend the LEGO Group as employer
#
#                                                      pros  \
# 0       Great people in some places, excellent Christm...
# 1       Majority of the people there are lovely, and t...
# 2        Nice environment, love people, not too stressful
# 3       -Great People\n-Heading in a good direction ge...
# 4       None, they lie about working hours, bonuses, p...
# ...                                                   ...
# 108622             It's fun to walk around the LEGO store
# 108623  Family owned and a great brand. Danish culture...
# 108624  It's a company with a clear purpose and one th...
# 108625  Great company values, awesome product, smart c...
# 108626  The LEGO Group is company with many opportunit...
#
#                                                      cons
# 0       Poor pay, huge gap for pay between senior mana...
# 1       Salaries are much lower than market competitor...
# 2                       Management can be clicky at times
# 3       -Low Salary\n-Middle Management likes to micro...
# 4       -Unachievable bonus unfairly set by manager\n-...
# ...                                                   ...
# 108622                          Doesn't pay a living wage
# 108623  A lot of bureaucracy, hard to make things happ...
# 108624  Being a global brand, compliance is important....
# 108625       Not very easy to transfer to other locations
# 108626  Many things are centralized in Denmark and rel...
#
# [108627 rows x 19 columns]

# %%
# Remoing all rows with null values
data_csv=data_csv.dropna()
data_csv
# Out:
#         Unnamed: 0                   firm date_review  \
# 0               50  AFH-Wealth-Management  2020-10-01
# 1               51  AFH-Wealth-Management  2021-02-05
# 2               52  AFH-Wealth-Management  2021-02-07
# 3               53  AFH-Wealth-Management  2021-02-07
# 4               60  AFH-Wealth-Management  2021-05-12
# ...            ...                    ...         ...
# 108622      838556         the-LEGO-Group  2021-05-21
# 108623      838558         the-LEGO-Group  2021-05-25
# 108624      838560         the-LEGO-Group  2021-05-31
# 108625      838561         the-LEGO-Group  2021-06-02
# 108626      838565         the-LEGO-Group  2021-06-04
#
#                                   job_title  \
# 0                      Office Administrator
# 1                           Quality Control
# 2                         IFA Administrator
# 3                     Investment Operations
# 4               Client Engagement Executive
# ...                                     ...
# 108622   Sales Associate (Brick Specialist)
# 108623               Senior Product Manager
# 108624           Senior Experience Designer
# 108625                    Marketing Manager
# 108626           Human Resources Specialist
#
#                                     current  \
# 0        Former Employee, more than 3 years
# 1                           Former Employee
# 2         Former Employee, less than 1 year
# 3         Former Employee, more than 1 year
# 4         Former Employee, less than 1 year
# ...                                     ...
# 108622    Former Employee, less than 1 year
# 108623                     Current Employee
# 108624   Current Employee, less than 1 year
# 108625  Current Employee, more than 5 years
# 108626  Current Employee, more than 3 years
#
#                                           location  overall_rating  \
# 0                     Bromsgrove, England, England               2
# 1                     Birmingham, England, England               1
# 2                     Bromsgrove, England, England               4
# 3                     Birmingham, England, England               3
# 4                     Birmingham, England, England               1
# ...                                            ...             ...
# 108622                             Bloomington, MN               4
# 108623                    London, England, England               4
# 108624                                     Billund               5
# 108625                   München, Bavaria, Bavaria               5
# 108626  Kladno, Central Bohemian, Central Bohemian               5
#
#         work_life_balance  culture_values  diversity_inclusion  career_opp  \
# 0                     1.0             3.0                  1.0         1.0
# 1                     3.0             1.0                  2.0         1.0
# 2                     3.0             3.0                  4.0         4.0
# 3                     5.0             5.0                  4.0         3.0
# 4                     1.0             2.0                  1.0         1.0
# ...                   ...             ...                  ...         ...
# 108622                5.0             4.0                  5.0         4.0
# 108623                3.0             4.0                  2.0         3.0
# 108624                5.0             5.0                  5.0         5.0
# 108625                4.0             5.0                  4.0         4.0
# 108626                4.0             5.0                  4.0         4.0
#
#         comp_benefits  senior_mgmt recommend ceo_approv outlook  \
# 0                 2.0          2.0         x          o       x
# 1                 1.0          1.0         x          o       o
# 2                 4.0          2.0         v          o       v
# 3                 1.0          2.0         x          o       v
# 4                 1.0          1.0         x          x       x
# ...               ...          ...       ...        ...     ...
# 108622            2.0          5.0         v          v       v
# 108623            2.0          3.0         v          r       v
# 108624            5.0          5.0         v          v       v
# 108625            4.0          4.0         v          v       v
# 108626            5.0          5.0         v          v       o
#
#                                                headline  \
# 0           The people both make and destroy this place
# 1                                     Very low salaries
# 2                                                  Good
# 3                                            AFH Review
# 4                       Terrible- avoid like the plague
# ...                                                 ...
# 108622                  Working at LEGO was pretty cool
# 108623                                    A great brand
# 108624                            Awesome place to work
# 108625           Just an awesome company to work for!!!
# 108626  I strongly recommend the LEGO Group as employer
#
#                                                      pros  \
# 0       Great people in some places, excellent Christm...
# 1       Majority of the people there are lovely, and t...
# 2        Nice environment, love people, not too stressful
# 3       -Great People\n-Heading in a good direction ge...
# 4       None, they lie about working hours, bonuses, p...
# ...                                                   ...
# 108622             It's fun to walk around the LEGO store
# 108623  Family owned and a great brand. Danish culture...
# 108624  It's a company with a clear purpose and one th...
# 108625  Great company values, awesome product, smart c...
# 108626  The LEGO Group is company with many opportunit...
#
#                                                      cons
# 0       Poor pay, huge gap for pay between senior mana...
# 1       Salaries are much lower than market competitor...
# 2                       Management can be clicky at times
# 3       -Low Salary\n-Middle Management likes to micro...
# 4       -Unachievable bonus unfairly set by manager\n-...
# ...                                                   ...
# 108622                          Doesn't pay a living wage
# 108623  A lot of bureaucracy, hard to make things happ...
# 108624  Being a global brand, compliance is important....
# 108625       Not very easy to transfer to other locations
# 108626  Many things are centralized in Denmark and rel...
#
# [108627 rows x 19 columns]

# %%
data_csv = data_csv.drop("Unnamed: 0", axis=1)

# %%
data_csv
# Out:
#                          firm date_review  \
# 0       AFH-Wealth-Management  2020-10-01
# 1       AFH-Wealth-Management  2021-02-05
# 2       AFH-Wealth-Management  2021-02-07
# 3       AFH-Wealth-Management  2021-02-07
# 4       AFH-Wealth-Management  2021-05-12
# ...                       ...         ...
# 108622         the-LEGO-Group  2021-05-21
# 108623         the-LEGO-Group  2021-05-25
# 108624         the-LEGO-Group  2021-05-31
# 108625         the-LEGO-Group  2021-06-02
# 108626         the-LEGO-Group  2021-06-04
#
#                                   job_title  \
# 0                      Office Administrator
# 1                           Quality Control
# 2                         IFA Administrator
# 3                     Investment Operations
# 4               Client Engagement Executive
# ...                                     ...
# 108622   Sales Associate (Brick Specialist)
# 108623               Senior Product Manager
# 108624           Senior Experience Designer
# 108625                    Marketing Manager
# 108626           Human Resources Specialist
#
#                                     current  \
# 0        Former Employee, more than 3 years
# 1                           Former Employee
# 2         Former Employee, less than 1 year
# 3         Former Employee, more than 1 year
# 4         Former Employee, less than 1 year
# ...                                     ...
# 108622    Former Employee, less than 1 year
# 108623                     Current Employee
# 108624   Current Employee, less than 1 year
# 108625  Current Employee, more than 5 years
# 108626  Current Employee, more than 3 years
#
#                                           location  overall_rating  \
# 0                     Bromsgrove, England, England               2
# 1                     Birmingham, England, England               1
# 2                     Bromsgrove, England, England               4
# 3                     Birmingham, England, England               3
# 4                     Birmingham, England, England               1
# ...                                            ...             ...
# 108622                             Bloomington, MN               4
# 108623                    London, England, England               4
# 108624                                     Billund               5
# 108625                   München, Bavaria, Bavaria               5
# 108626  Kladno, Central Bohemian, Central Bohemian               5
#
#         work_life_balance  culture_values  diversity_inclusion  career_opp  \
# 0                     1.0             3.0                  1.0         1.0
# 1                     3.0             1.0                  2.0         1.0
# 2                     3.0             3.0                  4.0         4.0
# 3                     5.0             5.0                  4.0         3.0
# 4                     1.0             2.0                  1.0         1.0
# ...                   ...             ...                  ...         ...
# 108622                5.0             4.0                  5.0         4.0
# 108623                3.0             4.0                  2.0         3.0
# 108624                5.0             5.0                  5.0         5.0
# 108625                4.0             5.0                  4.0         4.0
# 108626                4.0             5.0                  4.0         4.0
#
#         comp_benefits  senior_mgmt recommend ceo_approv outlook  \
# 0                 2.0          2.0         x          o       x
# 1                 1.0          1.0         x          o       o
# 2                 4.0          2.0         v          o       v
# 3                 1.0          2.0         x          o       v
# 4                 1.0          1.0         x          x       x
# ...               ...          ...       ...        ...     ...
# 108622            2.0          5.0         v          v       v
# 108623            2.0          3.0         v          r       v
# 108624            5.0          5.0         v          v       v
# 108625            4.0          4.0         v          v       v
# 108626            5.0          5.0         v          v       o
#
#                                                headline  \
# 0           The people both make and destroy this place
# 1                                     Very low salaries
# 2                                                  Good
# 3                                            AFH Review
# 4                       Terrible- avoid like the plague
# ...                                                 ...
# 108622                  Working at LEGO was pretty cool
# 108623                                    A great brand
# 108624                            Awesome place to work
# 108625           Just an awesome company to work for!!!
# 108626  I strongly recommend the LEGO Group as employer
#
#                                                      pros  \
# 0       Great people in some places, excellent Christm...
# 1       Majority of the people there are lovely, and t...
# 2        Nice environment, love people, not too stressful
# 3       -Great People\n-Heading in a good direction ge...
# 4       None, they lie about working hours, bonuses, p...
# ...                                                   ...
# 108622             It's fun to walk around the LEGO store
# 108623  Family owned and a great brand. Danish culture...
# 108624  It's a company with a clear purpose and one th...
# 108625  Great company values, awesome product, smart c...
# 108626  The LEGO Group is company with many opportunit...
#
#                                                      cons
# 0       Poor pay, huge gap for pay between senior mana...
# 1       Salaries are much lower than market competitor...
# 2                       Management can be clicky at times
# 3       -Low Salary\n-Middle Management likes to micro...
# 4       -Unachievable bonus unfairly set by manager\n-...
# ...                                                   ...
# 108622                          Doesn't pay a living wage
# 108623  A lot of bureaucracy, hard to make things happ...
# 108624  Being a global brand, compliance is important....
# 108625       Not very easy to transfer to other locations
# 108626  Many things are centralized in Denmark and rel...
#
# [108627 rows x 18 columns]

# %%
# Checking for duplicates
data_csv.duplicated().sum()
# Out:
# 4117

# %%
# Removing the duplicates
data_csv = data_csv.drop_duplicates()
data_csv
# Out:
#                          firm date_review  \
# 0       AFH-Wealth-Management  2020-10-01
# 1       AFH-Wealth-Management  2021-02-05
# 2       AFH-Wealth-Management  2021-02-07
# 3       AFH-Wealth-Management  2021-02-07
# 4       AFH-Wealth-Management  2021-05-12
# ...                       ...         ...
# 108622         the-LEGO-Group  2021-05-21
# 108623         the-LEGO-Group  2021-05-25
# 108624         the-LEGO-Group  2021-05-31
# 108625         the-LEGO-Group  2021-06-02
# 108626         the-LEGO-Group  2021-06-04
#
#                                   job_title  \
# 0                      Office Administrator
# 1                           Quality Control
# 2                         IFA Administrator
# 3                     Investment Operations
# 4               Client Engagement Executive
# ...                                     ...
# 108622   Sales Associate (Brick Specialist)
# 108623               Senior Product Manager
# 108624           Senior Experience Designer
# 108625                    Marketing Manager
# 108626           Human Resources Specialist
#
#                                     current  \
# 0        Former Employee, more than 3 years
# 1                           Former Employee
# 2         Former Employee, less than 1 year
# 3         Former Employee, more than 1 year
# 4         Former Employee, less than 1 year
# ...                                     ...
# 108622    Former Employee, less than 1 year
# 108623                     Current Employee
# 108624   Current Employee, less than 1 year
# 108625  Current Employee, more than 5 years
# 108626  Current Employee, more than 3 years
#
#                                           location  overall_rating  \
# 0                     Bromsgrove, England, England               2
# 1                     Birmingham, England, England               1
# 2                     Bromsgrove, England, England               4
# 3                     Birmingham, England, England               3
# 4                     Birmingham, England, England               1
# ...                                            ...             ...
# 108622                             Bloomington, MN               4
# 108623                    London, England, England               4
# 108624                                     Billund               5
# 108625                   München, Bavaria, Bavaria               5
# 108626  Kladno, Central Bohemian, Central Bohemian               5
#
#         work_life_balance  culture_values  diversity_inclusion  career_opp  \
# 0                     1.0             3.0                  1.0         1.0
# 1                     3.0             1.0                  2.0         1.0
# 2                     3.0             3.0                  4.0         4.0
# 3                     5.0             5.0                  4.0         3.0
# 4                     1.0             2.0                  1.0         1.0
# ...                   ...             ...                  ...         ...
# 108622                5.0             4.0                  5.0         4.0
# 108623                3.0             4.0                  2.0         3.0
# 108624                5.0             5.0                  5.0         5.0
# 108625                4.0             5.0                  4.0         4.0
# 108626                4.0             5.0                  4.0         4.0
#
#         comp_benefits  senior_mgmt recommend ceo_approv outlook  \
# 0                 2.0          2.0         x          o       x
# 1                 1.0          1.0         x          o       o
# 2                 4.0          2.0         v          o       v
# 3                 1.0          2.0         x          o       v
# 4                 1.0          1.0         x          x       x
# ...               ...          ...       ...        ...     ...
# 108622            2.0          5.0         v          v       v
# 108623            2.0          3.0         v          r       v
# 108624            5.0          5.0         v          v       v
# 108625            4.0          4.0         v          v       v
# 108626            5.0          5.0         v          v       o
#
#                                                headline  \
# 0           The people both make and destroy this place
# 1                                     Very low salaries
# 2                                                  Good
# 3                                            AFH Review
# 4                       Terrible- avoid like the plague
# ...                                                 ...
# 108622                  Working at LEGO was pretty cool
# 108623                                    A great brand
# 108624                            Awesome place to work
# 108625           Just an awesome company to work for!!!
# 108626  I strongly recommend the LEGO Group as employer
#
#                                                      pros  \
# 0       Great people in some places, excellent Christm...
# 1       Majority of the people there are lovely, and t...
# 2        Nice environment, love people, not too stressful
# 3       -Great People\n-Heading in a good direction ge...
# 4       None, they lie about working hours, bonuses, p...
# ...                                                   ...
# 108622             It's fun to walk around the LEGO store
# 108623  Family owned and a great brand. Danish culture...
# 108624  It's a company with a clear purpose and one th...
# 108625  Great company values, awesome product, smart c...
# 108626  The LEGO Group is company with many opportunit...
#
#                                                      cons
# 0       Poor pay, huge gap for pay between senior mana...
# 1       Salaries are much lower than market competitor...
# 2                       Management can be clicky at times
# 3       -Low Salary\n-Middle Management likes to micro...
# 4       -Unachievable bonus unfairly set by manager\n-...
# ...                                                   ...
# 108622                          Doesn't pay a living wage
# 108623  A lot of bureaucracy, hard to make things happ...
# 108624  Being a global brand, compliance is important....
# 108625       Not very easy to transfer to other locations
# 108626  Many things are centralized in Denmark and rel...
#
# [104510 rows x 18 columns]

# %%
# Checking for the data types
data_csv.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 104510 entries, 0 to 108626
# Data columns (total 18 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   firm                 104510 non-null  object
#  1   date_review          104510 non-null  object
#  2   job_title            104510 non-null  object
#  3   current              104510 non-null  object
#  4   location             104510 non-null  object
#  5   overall_rating       104510 non-null  int64
#  6   work_life_balance    104510 non-null  float64
#  7   culture_values       104510 non-null  float64
#  8   diversity_inclusion  104510 non-null  float64
#  9   career_opp           104510 non-null  float64
#  10  comp_benefits        104510 non-null  float64
#  11  senior_mgmt          104510 non-null  float64
#  12  recommend            104510 non-null  object
#  13  ceo_approv           104510 non-null  object
#  14  outlook              104510 non-null  object
#  15  headline             104510 non-null  object
#  16  pros                 104510 non-null  object
#  17  cons                 104510 non-null  object
# dtypes: float64(6), int64(1), object(11)
# memory usage: 15.1+ MB

# %%
# Checking for  number of  unique values across all columns
data_csv.nunique()
# Out:
# firm                      421
# date_review               271
# job_title               18440
# current                    20
# location                 6229
# overall_rating              5
# work_life_balance           5
# culture_values              5
# diversity_inclusion         5
# career_opp                  5
# comp_benefits               5
# senior_mgmt                 5
# recommend                   3
# ceo_approv                  4
# outlook                     4
# headline                55856
# pros                   102073
# cons                   101645
# dtype: int64

# %% [markdown]
# ## taking only numeric variable

# %%
# Create data
X= data_csv[['work_life_balance','culture_values','diversity_inclusion','career_opp','comp_benefits','senior_mgmt']]
y= data_csv['overall_rating']
X_train, X_test, y_train, y_test = train_test_split(X_dummies, y, random_state=1)

# %%
#One-hot encoding the entire dataframe
#X_dummies = X_dummies.drop('Unnamed: 0', axis=1)
#X_dummies = pd.get_dummies(X)

# %% [markdown]
# # DecisionTree
# A decision tree is one of the supervised machine learning algorithms. This algorithm can be used for regression and classification problems — yet, is mostly used for classification problems. A decision tree follows a set of if-else conditions to visualize the data and classify it according to the conditions.

# %%
clf = DecisionTreeClassifier().fit(X_train, y_train)
y_pred = clf.predict(X_test)
confusion_matrix(y_test, y_pred)
# Out:
# array([[ 956,  318,  180,   29,   27],
#        [ 324,  600,  675,  119,   33],
#        [ 163,  575, 2724, 1516,  300],
#        [  33,  118, 1560, 4954, 1870],
#        [  21,   40,  368, 2218, 6407]], dtype=int64)

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            1       0.64      0.63      0.64      1510
#            2       0.36      0.34      0.35      1751
#            3       0.49      0.52      0.51      5278
#            4       0.56      0.58      0.57      8535
#            5       0.74      0.71      0.72      9054
#
#     accuracy                           0.60     26128
#    macro avg       0.56      0.56      0.56     26128
# weighted avg       0.60      0.60      0.60     26128

# %%
#Traning ,testing score
print(f'Training Score: {clf.score(X_train, y_train)}')
print(f'Testing Score: {clf.score(X_test, y_test)}')
# Out:
# Training Score: 0.9443877420836416
# Testing Score: 0.5986298224127373

# %% [markdown]
# # Appling random forest Classifier

# %% [markdown]
# from sklearn.ensemble import RandomForestClassifier
# clf = RandomForestClassifier(random_state=1, n_estimators=50).fit(X_train, y_train)
# print(f'Training Score: {clf.score(X_train, y_train)}')
# print(f'Testing Score: {clf.score(X_test, y_test)}')

# %% [markdown]
# # Bagging
# Instead of having one decision tree, we make 50 random trees and average their output. Decision trees try to make the best decision possible at every point. So if we use the same input, we'll get the same decision tree each time. (And, we won't get a different answer after aggregating.) To get different trees, we give them different inputs by randomly sampling the input dataset. Random sampling with replacement is known as bootstrapping. (We use replacement because a data point might occur multiple times in the random sample.) This method of creating a random ensemble is known as bootstrap aggregating, or bagging.

# %%
clfs = []
scores = []
for i in range(50):
    
    # Sample the data for each new tree
    X_train_scaled_bootstrap, y_train_bootstrap = resample(X_train, y_train, random_state=i)
    
    # Create a decision tree and append it to our list of classifiers
    clf = DecisionTreeClassifier(random_state=i+200).fit(X_train_scaled_bootstrap, y_train_bootstrap)
    clfs.append(clf)
    
    # Take the median score of all the created classifiers
    y_preds = [clf.predict(X_test) for clf in clfs]
    y_pred = pd.DataFrame(y_preds).median().round()
    score = score = accuracy_score(y_test, y_pred)
    scores.append(score)

plt.plot(scores)
plt.show()
print(f'score: {score}')
# Out:
# score: 0.6355251071647275

# %% [markdown]
# # This algorithm is known as "Extremely Random Trees"
# or ExtraTrees in scikit-learn

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import ExtraTreesClassifier
clf = ExtraTreesClassifier(random_state=1, n_estimators=50).fit(X_train, y_train)
print(f'Training Score: {clf.score(X_train, y_train)}')
print(f'Testing Score: {clf.score(X_test, y_test)}')
# Out:
# Training Score: 0.9443877420836416
# Testing Score: 0.6290186772810777

# %% [markdown]
# # K-nearest neighbors

# %%
knn = KNeighborsClassifier(n_neighbors=9)
knn.fit(X_train, y_train)
print('k=9 Test Acc: %.3f' % knn.score(X_test, y_test))
# Out:
# k=9 Test Acc: 0.644
